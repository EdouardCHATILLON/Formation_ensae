# %%
# Décommenter la ligne suivante pour installer lxml (nécessaire pour read_html)
#%pip install lxml

# %%
import pandas as pd
import requests

from bs4 import BeautifulSoup

# %%
url='https://geco.amf-france.org/produit-d-epargne/part/1487'
r=requests.get(url, headers={"User-Agent": "CepeBot_EC"})
r.raise_for_status()
test_soup = BeautifulSoup(r.text, "html.parser")
print(str(test_soup)[:300] + "...")
# Out:
# <!DOCTYPE html>
#
# <html class="max-w-full overflow-x-hidden" data-critters-container="" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>GECO.FO-FRONT</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="./assets/images/icons/favicon.ico" rel="sho...

# %%
css_selector = "tr.table_row-style"
etf= test_soup.select(css_selector)
print(etf)
# Out:
# []

# %%
url = f"https://geco.amf-france.org/api/produits/part/1487"
    
response = requests.get(url, headers={"User-Agent": "CepeBot"})
response.raise_for_status()

print(response.text[:800] + "...")
# Out:
# <!doctype html>
# <html lang="en" class=" max-w-full overflow-x-hidden" data-critters-container>
# <head>
#   <meta charset="utf-8">
#   <title>GECO.FO-FRONT</title>
#   <base href="/">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <link rel="shortcut icon" type="image/vnd.microsoft.icon" href="./assets/images/icons/favicon.ico">
#   <link rel="preconnect" href="https://fonts.gstatic.com">
# <style>@import"https://fonts.googleapis.com/css?family=Montserrat:300,400,500,700&display=swap";@import"https://use.typekit.net/rsd4jho.css";:root{font-family:-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica,Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji",Segoe UI Symbol;--font-family:-apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-ser...

# %%
#Selon chat gpt il vaut mieux utiliser l'API interne du site
import requests

def get_vl(part_id):
    url = f"https://geco.amf-france.org/api/produits/part/{part_id}"
    
    response = requests.get(url, headers={"User-Agent": "CepeBot"})
    response.raise_for_status()
    
    soup = BeautifulSoup(r.text, "html.parser") # HTML parser de Python
    print(str(soup)[:700] + "...")
    css_selector = "div tr.table-row-style ng-star-inserted"
    data_vl= soup.select(css_selector)

    return data_vl
    

result = get_vl(1487)

print(result)
# Out:
# <!DOCTYPE html>
#
# <html class="max-w-full overflow-x-hidden" data-critters-container="" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>GECO.FO-FRONT</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="./assets/images/icons/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <style>@import"https://fonts.googleapis.com/css?family=Montserrat:300,400,500,700&display=swap";@import"https://use.typekit.net/rsd4jho.css";:root{font-family:-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica,Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji",Segoe UI Symbol;--font-f...
# []

# %%
result.text
# Out:
# '<!doctype html>\r\n<html lang="en" class=" max-w-full overflow-x-hidden" data-critters-container>\r\n<head>\r\n  <meta charset="utf-8">\r\n  <title>GECO.FO-FRONT</title>\r\n  <base href="/">\r\n  <meta name="viewport" content="width=device-width, initial-scale=1">\r\n  <link rel="shortcut icon" type="image/vnd.microsoft.icon" href="./assets/images/icons/favicon.ico">\r\n  <link rel="preconnect" href="https://fonts.gstatic.com">\r\n<style>@import"https://fonts.googleapis.com/css?family=Montserrat:300,400,500,700&display=swap";@import"https://use.typekit.net/rsd4jho.css";:root{font-family:-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica,Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji",Segoe UI Symbol;--font-family:-apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-serif, "Apple Color Emoji", "Segoe UI Emoji", "Segoe UI Symbol";--surface-a:#ffffff;--surface-b:#f8f9fa;--surface-c:#e9ecef;--surface-d:#dee2e6;--surface-e:#ffffff;--surface-f:#fffff
# ...
