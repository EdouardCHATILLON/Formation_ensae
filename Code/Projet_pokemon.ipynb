# %%
import pandas as pd
import requests

from bs4 import BeautifulSoup

# %% [markdown]
# Etape 1 - Webscraping

# %%
base_url = "https://scrapeme.live/product-category/pokemon"
page_url="/page/30/"

url=base_url+page_url

r=requests.get(url)
r.raise_for_status()

print(r.text[:800] + "...")
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" class="no-js no-svg">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="profile" href="http://gmpg.org/xfn/11">
#
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <title>Pokemon &#8211; Page 30 &#8211; ScrapeMe</title>
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link href='https://fonts.gstatic.com' crossorigin rel='preconnect' />
# <link rel="alternate" type="application/rss+xml" title="ScrapeMe &raquo; Feed" href="https://scrapeme.live/feed/" />
# <link rel="alternate" type="application/rss+xml" title="ScrapeMe &raquo; Comments Feed" href="https://scrapeme.live/comments...

# %%
soup = BeautifulSoup(r.text, "html.parser") # HTML parser de Python
print(str(soup)[:700] + "...")
# Out:
# <!DOCTYPE html>
#
# <html class="no-js no-svg" lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <title>Pokemon – Page 30 – ScrapeMe</title>
# <link href="//fonts.googleapis.com" rel="dns-prefetch">
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://scrapeme.live/feed/" rel="alternate" title="ScrapeMe » Feed" type="application/rss+xml"/>
# <link href="https://scrapeme.live/comment...

# %%
#Liste nom
css_selector = "li.product h2.woocommerce-loop-product__title "
list_name= soup.select(css_selector)

print('nb objet '+str(len(list_name)))
for elem in list_poke:
    print(elem.text)
# Out:
# nb objet 16
# Uxie
# Mesprit
# Azelf
# Dialga
# Palkia
# Heatran
# Regigigas
# Cresselia
# Phione
# Manaphy
# Darkrai
# Arceus
# Victini
# Snivy
# Servine
# Serperior

# %%
#liste prix
css_selector = "li.product span.woocommerce-Price-amount"
list_price= soup.select(css_selector)

print('nb objet '+str(len(list_price)))
for elem in list_price:
    print(elem.text.replace('£',''))
# Out:
# nb objet 16
# 200.00
# 25.00
# 32.00
# 179.00
# 151.00
# 142.00
# 77.00
# 34.00
# 155.00
# 74.00
# 59.00
# 53.00
# 109.00
# 102.00
# 154.00
# 88.00
